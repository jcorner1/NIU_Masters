# %% [markdown]
# # Download Radiosonde Data and Calculate Parameters Significant to Tornadogensis.

# %%
import siphon
from siphon.simplewebservice.wyoming import WyomingUpperAir

import metpy
import matplotlib.pyplot as plt
from metpy.plots import SkewT
import metpy.calc as calcs
from metpy.units import units

import numpy as np
import pandas as pd

from datetime import datetime
import time

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## List of Stations with Radiosonde Data
# Here is a list of all the staions with data. This includes some stations in Canada to get a complete raster of the CONUS. Data is pulled from https://weather.uwyo.edu/upperair/sounding.html

# %%
hours = [0, 12]
Stations = ['UIL', 'SLE', 'MFR', 'OAK', 'NKX', 'OTX', 'BOI', 'REV', 'LKN', 'VEF', 'TFX', 'SLC', 'FGZ', 'TUS', 'GGW', 'ABQ', 'EPZ', 'DNR',
            'BIS', 'ABR', 'OAX', 'LBF', 'DDC', 'TOP', 'OUN', 'AMA', 'MAF', 'FWD', 'DRT', 'CRP', 'BRO', 'INL', 'MPX', 'DVN', 'SGF', 'LZK',
            'SHV', 'LCH', 'LIX', 'JAN', 'ILX', 'GRB', 'APX', 'DTX', 'ILN', 'BMX', 'FFC', 'TBW', 'EYW', 'MFL', 'JAX', 'CHS', 'MHX',
            'RNK', 'WAL', 'BUF', 'WAL', 'OKX', 'CHH', 'GYX', 'CAR', 'TLH', 'IAQ', 'ALB', 'BUF', 'AWE', 'YQI', 'WMW', 'WPL', 'VQD', 'WSE', 'YZT']

# %% [markdown]
# ## Data Creation Loops

# %%
before = datetime.now()

#Open the text file that values will be printed to.
file_object = open('sonde_data_dec_2019.txt', 'a')

#Interate through the list of radiosonde stations
for station in Stations:
    
    #Reset/preset the lists
    row=[]
    srh_tot=[]
    cape_tot=[]
    dew_tot=[]
    
    #Interate through the day and hours of radiosonde luanches
    for day in range(30):
        for hour in hours:
        
            #Use a try statement to keep the program running if data or the server isn't availble
            try:
                
                #Request the data
                request_time = datetime(2019, 12, day+1, hour)
                df = WyomingUpperAir.request_data(request_time, station)

                #grab different values
                u = df.u_wind.values * units.knot
                v = df.v_wind.values * units.knot
                h = df.height.values * units.meter
                p = df.pressure.values * units.hPa
                d = df.dewpoint.values * units.celsius
                t = df.temperature.values * units.celsius
                lat = df.latitude.values
                lon = df.longitude.values
                
                #Calculate tornado parameters using MetPy and append values
                cape, cin = calcs.surface_based_cape_cin(p, t, d)
                srh_1_pos, srh_1_neg, srh_1_tot = calcs.storm_relative_helicity(h, u, v, 1000 * units.meter)
                srh_tot.append(srh_1_tot.m)
                cape_tot.append(cape.m)
                dew_tot.append(d.m[0])

            #Skip any timeslots that don't have data
            #If the server is slow, the script will sleep and then restart a minute later
            except ValueError:
                print(f"there is no data for {day+1} at {hour} at {station}.")
                pass

            except:
                print(f"Waiting for this slow ass server to hurry up. {station} is being skipped")
                time.sleep(60)
                pass
        
    row.append((f'{station}, {np.average(srh_tot)}, {np.average(cape_tot)}, {np.average(dew_tot)}, {sum(shear >= 100 for shear in srh_tot)}, {sum(capes >= 1000 for capes in cape_tot)}, {sum(dews >= 12.8 for dews in dew_tot)}, {lat[0]}, {lon[0]} \n’'))
    print(row)

    #write the values calculated to the text file
    file_object.write(f'{station}, {np.average(srh_tot)}, {np.average(cape_tot)}, {np.average(dew_tot)}, {sum(shear >= 100 for shear in srh_tot)}, {sum(capes >= 1000 for capes in cape_tot)}, {sum(dews >= 12.8 for dews in dew_tot)}, {lat[0]}, {lon[0]} \n')
    
#close the text file    
file_object.close()
after = datetime.now()
print(after - before)
# Out:
# ['UIL, 70.74142737981248, 10.302740817130685, 4.976666666666666, 16, 0, 0, 47.95, -124.55 \n’']
# ['SLE, 34.720521156560444, 10.376863252165888, 4.648333333333334, 6, 0, 0, 44.91, -123.0 \n’']
# ['MFR, 21.52409440160663, 16.908814527771366, 2.9366666666666665, 1, 0, 0, 42.36, -122.86 \n’']
# there is no data for 15 at 0 at OAK.
# there is no data for 15 at 12 at OAK.
# there is no data for 16 at 0 at OAK.
# there is no data for 16 at 12 at OAK.
# ['OAK, 43.885101252676, 13.159602687036962, 8.489285714285714, 8, 0, 5, 37.73, -122.21 \n’']
# Waiting for this slow ass server to hurry up. NKX is being skipped
# Waiting for this slow ass server to hurry up. NKX is being skipped
# Waiting for this slow ass server to hurry up. NKX is being skipped
# ['NKX, 4.2284503355206455, 58.650491085771506, 8.945614035087718, 0, 0, 14, 32.85, -117.12 \n’']
# Waiting for this slow ass server to hurry up. OTX is being skipped
# Waiting for this slow ass server to hurry up. OTX is being skipped
# ['OTX, 50.96416863186374, 2.2096335968571843, -1.5689655172413792, 6, 0, 0, 47.68, -117.63 \n’']
# Waiting for this slow ass server to hurry up. BOI is being skipped
# ['BOI, 26.74815775184714, 4.516965847969178, -1.5101694915254238, 4, 0, 0, 43.56, -116.21 \n’']
# ['REV, 24.082897884518683, 2.507437411031134, -2.7316666666666665, 4, 0, 0, 39.56, -119.8 \n’']
# there is no data for 5 at 0 at LKN.
# there is no data for 14 at 0 at LKN.
# ['LKN, 40.075564518433126, 4.615600569162913, -4.877586206896552, 6, 0, 0, 40.86, -115.73 \n’']
# ['VEF, 12.07342660708144, 8.59749529225855, -0.6916666666666668, 0, 0, 0, 36.05, -115.18 \n’']
# ['TFX, 112.82311944387722, 2.3924831925073513, -6.531666666666667, 29, 0, 0, 47.46, -111.39 \n’']
# Waiting for this slow ass server to hurry up. SLC is being skipped
# ['SLC, 10.25674904376272, 9.334222160104504, -2.569491525423729, 1, 0, 0, 40.77, -111.95 \n’']
# ['FGZ, 15.320451360562775, 6.720001934326523, -6.826666666666667, 3, 0, 0, 35.23, -111.82 \n’']
# ['TUS, 8.623660926793946, 13.038194089303383, 0.5450000000000002, 0, 0, 0, 32.23, -110.96 \n’']
# ['GGW, 57.048264902095376, 1.4598844372121962, -8.148333333333333, 9, 0, 0, 48.21, -106.61 \n’']
# ['ABQ, -0.20700121437497418, 6.40386320890233, -4.378333333333333, 4, 0, 0, 35.04, -106.62 \n’']
# ['EPZ, 8.604365751916797, 1.2502398249943325, -2.206666666666666, 3, 0, 0, 31.86, -106.7 \n’']
# there is no data for 6 at 12 at DNR.
# ['DNR, 7.52215875606188, 2.788627862810383, -7.744067796610169, 0, 0, 0, 39.77, -104.87 \n’']
# Waiting for this slow ass server to hurry up. BIS is being skipped
# ['BIS, 55.55436825109507, 0.27754325911990696, -9.374576271186442, 14, 0, 0, 46.76, -100.75 \n’']
# ['ABR, 71.57556476305122, 0.31221062952753953, -9.18, 17, 0, 0, 45.45, -98.43 \n’']
# there is no data for 15 at 0 at OAX.
# there is no data for 15 at 12 at OAX.
# there is no data for 16 at 0 at OAX.
# ['OAX, 76.09054295276347, 1.2815190712263516, -3.2631578947368416, 19, 0, 0, 41.31, -96.36 \n’']
# ['LBF, 34.33396121897181, 0.5744766393079012, -4.46, 10, 0, 0, 41.13, -100.68 \n’']
# Waiting for this slow ass server to hurry up. DDC is being skipped
# Waiting for this slow ass server to hurry up. DDC is being skipped
# Waiting for this slow ass server to hurry up. DDC is being skipped
# ['DDC, 61.63483985989186, -0.022684225602351397, -4.847368421052632, 14, 0, 0, 37.76, -99.97 \n’']
# ['TOP, 45.19538563850428, 0.5898047653805505, -2.4283333333333332, 10, 0, 0, 39.07, -95.62 \n’']
# ['OUN, 59.64918325672661, -0.6108310283417567, 0.5833333333333334, 13, 0, 2, 35.18, -97.44 \n’']
# Waiting for this slow ass server to hurry up. AMA is being skipped
# Waiting for this slow ass server to hurry up. AMA is being skipped
# ['AMA, 29.14446506672293, 1.7463739417463533, -4.48103448275862, 10, 0, 0, 35.23, -101.7 \n’']
# Waiting for this slow ass server to hurry up. MAF is being skipped
# ['MAF, 6.549484534631333, 11.152355595746089, -1.3847457627118642, 3, 0, 0, 31.95, -102.18 \n’']
# ['FWD, 56.88923204461775, -5.678514707918095, 4.201666666666666, 17, 0, 8, 32.83, -97.3 \n’']
# there is no data for 17 at 12 at DRT.
# ['DRT, 25.379701338759475, 8.364317230976118, 1.7169491525423728, 8, 0, 5, 29.36, -100.91 \n’']
# there is no data for 23 at 12 at CRP.
# there is no data for 27 at 0 at CRP.
# ['CRP, 35.66553742072446, 207.5877351615049, 12.270689655172415, 11, 5, 29, 27.76, -97.5 \n’']
# ['BRO, 11.654558017952905, 67.2389370308696, 13.036666666666667, 4, 1, 35, 25.91, -97.41 \n’']
# ['INL, 84.8817291995796, 0.9743863278581145, -12.068333333333335, 19, 0, 0, 48.56, -93.4 \n’']
# ['MPX, 61.2305845567867, 1.016262264746212, -7.358333333333333, 13, 0, 0, 44.85, -93.56 \n’']
# ['DVN, 77.12138462283583, 1.2357160562623746, -2.351666666666667, 19, 0, 0, 41.61, -90.58 \n’']
# ['SGF, 81.44433546044105, 1.1772673035327166, -0.2333333333333333, 21, 0, 1, 37.23, -93.38 \n’']
# there is no data for 6 at 12 at LZK.
# ['LZK, 40.344048180905645, 2.4955765864075716, 2.377966101694915, 9, 0, 4, 34.84, -92.26 \n’']
# ['SHV, 44.30301093885058, 38.7360936341256, 6.0, 9, 0, 10, 32.46, -93.78 \n’']
# ['LCH, 37.135477226540004, 99.49148729969868, 9.37, 12, 4, 19, 30.11, -93.21 \n’']
# ['LIX, 46.22802315783772, 30.881998321934102, 10.091666666666667, 11, 1, 21, 30.34, -89.83 \n’']
# ['JAN, 50.96302467708045, -1.1707703513956402, 6.4416666666666655, 13, 0, 14, 32.32, -90.08 \n’']
# ['ILX, 64.46032618270776, 1.3675412271767156, -1.2216666666666667, 16, 0, 0, 40.15, -89.33 \n’']
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/metpy/interpolate/one_dimension.py:157: RuntimeWarning: invalid value encountered in true_divide
#   var_interp = var[below] + (var[above] - var[below]) * ((x_array - xp[below])
# ['GRB, 72.5612072987232, 0.2938190724703135, -5.508333333333334, 19, 0, 0, 44.5, -88.11 \n’']
# ['APX, 79.01678029630125, 2.9719551511799387, -5.043333333333334, 19, 0, 0, 44.91, -84.71 \n’']
# there is no data for 2 at 0 at DTX.
# there is no data for 2 at 12 at DTX.
# there is no data for 3 at 0 at DTX.
# there is no data for 3 at 12 at DTX.
# there is no data for 24 at 12 at DTX.
# ['DTX, 93.96550505731483, 1.5817110377414776, -2.878181818181818, 22, 0, 0, 42.7, -83.46 \n’']
# ['ILN, 69.63780809680864, 3.737962057592541, 0.2016666666666667, 17, 0, 1, 39.41, -83.81 \n’']
# ['BMX, 66.00387649400537, 20.50170690313696, 6.4700000000000015, 23, 0, 12, 33.16, -86.76 \n’']
# Waiting for this slow ass server to hurry up. FFC is being skipped
# ['FFC, 53.51601749790479, 1.7761618311124705, 5.569491525423728, 11, 0, 11, 33.36, -84.57 \n’']
# there is no data for 13 at 0 at TBW.
# Waiting for this slow ass server to hurry up. TBW is being skipped
# ['TBW, 44.779870168232044, 239.52174898572287, 15.879310344827585, 16, 5, 41, 27.7, -82.4 \n’']
# Waiting for this slow ass server to hurry up. EYW is being skipped
# ['EYW, 27.263179849960498, 528.0144292753765, 19.566101694915258, 8, 11, 57, 24.55, -81.79 \n’']
# there is no data for 7 at 0 at MFL.
# Waiting for this slow ass server to hurry up. MFL is being skipped
# ['MFL, 16.82962069408882, 182.57562216325044, 18.04655172413793, 1, 5, 52, 25.75, -80.38 \n’']
# Waiting for this slow ass server to hurry up. JAX is being skipped
# ['JAX, 41.67127083920866, 70.36120903430857, 12.813559322033898, 11, 1, 35, 30.5, -81.7 \n’']
# ['CHS, 69.41841654239465, 4.829178923896301, 8.368333333333334, 18, 0, 19, 32.9, -80.03 \n’']
# ['MHX, 52.70822157118015, 0.2663315378805559, 6.8916666666666675, 15, 0, 14, 34.78, -76.88 \n’']
# ['RNK, 37.85136973006616, 133.37584468503857, 0.006666666666666525, 10, 1, 2, 37.2, -80.41 \n’']
# ['WAL, 45.2259529168132, 1.3688479877791073, 0.9300000000000002, 17, 0, 4, 37.93, -75.47 \n’']
# Waiting for this slow ass server to hurry up. BUF is being skipped
# ['BUF, 88.0583322989555, 1.600269082902835, -2.98135593220339, 20, 0, 0, 42.93, -78.73 \n’']
# ['WAL, 45.2259529168132, 1.3688479877791073, 0.9300000000000002, 17, 0, 4, 37.93, -75.47 \n’']
# there is no data for 6 at 0 at OKX.
# ['OKX, 61.13021820750176, 1.0018768995104543, -1.1542372881355933, 16, 0, 1, 40.87, -72.86 \n’']
# there is no data for 1 at 0 at CHH.
# there is no data for 2 at 0 at CHH.
# there is no data for 3 at 0 at CHH.
# there is no data for 4 at 0 at CHH.
# there is no data for 5 at 0 at CHH.
# there is no data for 6 at 0 at CHH.
# there is no data for 7 at 0 at CHH.
# there is no data for 8 at 0 at CHH.
# there is no data for 9 at 0 at CHH.
# there is no data for 10 at 0 at CHH.
# there is no data for 11 at 0 at CHH.
# there is no data for 12 at 0 at CHH.
# there is no data for 13 at 0 at CHH.
# there is no data for 14 at 0 at CHH.
# there is no data for 15 at 0 at CHH.
# there is no data for 16 at 0 at CHH.
# there is no data for 17 at 0 at CHH.
# there is no data for 18 at 0 at CHH.
# there is no data for 19 at 0 at CHH.
# there is no data for 20 at 0 at CHH.
# there is no data for 21 at 0 at CHH.
# there is no data for 21 at 12 at CHH.
# there is no data for 22 at 0 at CHH.
# there is no data for 23 at 0 at CHH.
# there is no data for 24 at 0 at CHH.
# there is no data for 25 at 0 at CHH.
# there is no data for 26 at 0 at CHH.
# there is no data for 27 at 0 at CHH.
# there is no data for 28 at 0 at CHH.
# there is no data for 30 at 0 at CHH.
# ['CHH, 49.65884684778855, 8.340810227167314, 0.7766666666666666, 6, 0, 0, 41.66, -69.96 \n’']
# ['GYX, 79.53898030816794, 1.866698435231037, -7.216666666666667, 18, 0, 0, 43.9, -70.25 \n’']
# there is no data for 12 at 12 at CAR.
# ['CAR, 79.24907945503044, 0.7577421858097247, -9.476271186440679, 21, 0, 0, 46.86, -68.01 \n’']
# there is no data for 1 at 0 at TLH.
# there is no data for 1 at 12 at TLH.
# there is no data for 2 at 0 at TLH.
# there is no data for 2 at 12 at TLH.
# ['TLH, 70.42387592091725, -6.801612541281645, 10.251785714285713, 14, 0, 18, 30.45, -84.3 \n’']
# there is no data for 1 at 0 at IAQ.
# there is no data for 1 at 12 at IAQ.
# there is no data for 2 at 0 at IAQ.
# there is no data for 2 at 12 at IAQ.
# there is no data for 3 at 0 at IAQ.
# there is no data for 3 at 12 at IAQ.
# there is no data for 4 at 0 at IAQ.
# there is no data for 4 at 12 at IAQ.
# there is no data for 5 at 0 at IAQ.
# there is no data for 5 at 12 at IAQ.
# there is no data for 6 at 0 at IAQ.
# there is no data for 6 at 12 at IAQ.
# there is no data for 7 at 0 at IAQ.
# there is no data for 7 at 12 at IAQ.
# there is no data for 8 at 0 at IAQ.
# there is no data for 8 at 12 at IAQ.
# there is no data for 9 at 0 at IAQ.
# there is no data for 9 at 12 at IAQ.
# there is no data for 10 at 0 at IAQ.
# there is no data for 10 at 12 at IAQ.
# there is no data for 11 at 0 at IAQ.
# there is no data for 11 at 12 at IAQ.
# there is no data for 12 at 0 at IAQ.
# there is no data for 12 at 12 at IAQ.
# there is no data for 13 at 0 at IAQ.
# there is no data for 13 at 12 at IAQ.
# there is no data for 14 at 0 at IAQ.
# there is no data for 14 at 12 at IAQ.
# there is no data for 15 at 0 at IAQ.
# there is no data for 15 at 12 at IAQ.
# there is no data for 16 at 0 at IAQ.
# there is no data for 16 at 12 at IAQ.
# there is no data for 17 at 0 at IAQ.
# there is no data for 17 at 12 at IAQ.
# there is no data for 18 at 0 at IAQ.
# there is no data for 18 at 12 at IAQ.
# there is no data for 19 at 0 at IAQ.
# there is no data for 19 at 12 at IAQ.
# there is no data for 20 at 0 at IAQ.
# there is no data for 20 at 12 at IAQ.
# there is no data for 21 at 0 at IAQ.
# there is no data for 21 at 12 at IAQ.
# there is no data for 22 at 0 at IAQ.
# there is no data for 22 at 12 at IAQ.
# there is no data for 23 at 0 at IAQ.
# there is no data for 23 at 12 at IAQ.
# there is no data for 24 at 0 at IAQ.
# there is no data for 24 at 12 at IAQ.
# there is no data for 25 at 0 at IAQ.
# there is no data for 25 at 12 at IAQ.
# there is no data for 26 at 0 at IAQ.
# there is no data for 26 at 12 at IAQ.
# there is no data for 27 at 0 at IAQ.
# there is no data for 27 at 12 at IAQ.
# there is no data for 28 at 0 at IAQ.
# there is no data for 28 at 12 at IAQ.
# there is no data for 29 at 0 at IAQ.
# there is no data for 29 at 12 at IAQ.
# there is no data for 30 at 0 at IAQ.
# there is no data for 30 at 12 at IAQ.
# ['IAQ, nan, nan, nan, 0, 0, 0, 30.45, -84.3 \n’']
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/lib/function_base.py:495: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['ALB, 67.60105093658852, 1.8213086784171337, -5.138333333333334, 16, 0, 0, 42.69, -73.83 \n’']
# ['BUF, 87.10591149889107, 1.5735979315211213, -3.0316666666666663, 20, 0, 0, 42.93, -78.73 \n’']
# there is no data for 1 at 0 at AWE.
# there is no data for 1 at 12 at AWE.
# there is no data for 2 at 0 at AWE.
# there is no data for 2 at 12 at AWE.
# there is no data for 3 at 0 at AWE.
# there is no data for 3 at 12 at AWE.
# there is no data for 4 at 0 at AWE.
# there is no data for 4 at 12 at AWE.
# there is no data for 5 at 0 at AWE.
# there is no data for 5 at 12 at AWE.
# there is no data for 6 at 0 at AWE.
# there is no data for 6 at 12 at AWE.
# there is no data for 7 at 0 at AWE.
# there is no data for 7 at 12 at AWE.
# there is no data for 8 at 0 at AWE.
# there is no data for 8 at 12 at AWE.
# there is no data for 9 at 0 at AWE.
# there is no data for 9 at 12 at AWE.
# there is no data for 10 at 0 at AWE.
# there is no data for 10 at 12 at AWE.
# there is no data for 11 at 0 at AWE.
# there is no data for 11 at 12 at AWE.
# there is no data for 12 at 0 at AWE.
# there is no data for 12 at 12 at AWE.
# there is no data for 13 at 0 at AWE.
# there is no data for 13 at 12 at AWE.
# there is no data for 14 at 0 at AWE.
# there is no data for 14 at 12 at AWE.
# there is no data for 15 at 0 at AWE.
# there is no data for 15 at 12 at AWE.
# there is no data for 16 at 0 at AWE.
# there is no data for 16 at 12 at AWE.
# there is no data for 17 at 0 at AWE.
# there is no data for 17 at 12 at AWE.
# there is no data for 18 at 0 at AWE.
# there is no data for 18 at 12 at AWE.
# there is no data for 19 at 0 at AWE.
# there is no data for 19 at 12 at AWE.
# there is no data for 20 at 0 at AWE.
# there is no data for 20 at 12 at AWE.
# there is no data for 21 at 0 at AWE.
# there is no data for 21 at 12 at AWE.
# there is no data for 22 at 0 at AWE.
# there is no data for 22 at 12 at AWE.
# there is no data for 23 at 0 at AWE.
# there is no data for 23 at 12 at AWE.
# there is no data for 24 at 0 at AWE.
# there is no data for 24 at 12 at AWE.
# there is no data for 25 at 0 at AWE.
# there is no data for 25 at 12 at AWE.
# there is no data for 26 at 0 at AWE.
# there is no data for 26 at 12 at AWE.
# there is no data for 27 at 0 at AWE.
# there is no data for 27 at 12 at AWE.
# there is no data for 28 at 0 at AWE.
# there is no data for 28 at 12 at AWE.
# there is no data for 29 at 0 at AWE.
# there is no data for 29 at 12 at AWE.
# there is no data for 30 at 0 at AWE.
# there is no data for 30 at 12 at AWE.
# ['AWE, nan, nan, nan, 0, 0, 0, 42.93, -78.73 \n’']
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/lib/function_base.py:495: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['YQI, 51.07996953894193, 0.811602364383074, -2.5733333333333333, 13, 0, 1, 43.87, -66.11 \n’']
# ['WMW, 75.54268700405177, 1.3049346535792086, -9.701666666666664, 20, 0, 0, 46.3, -76.01 \n’']
# ['WPL, 59.805650330883324, 0.04052261144302425, -17.241666666666667, 14, 0, 0, 51.45, -90.22 \n’']
# there is no data for 1 at 0 at VQD.
# there is no data for 1 at 12 at VQD.
# there is no data for 2 at 0 at VQD.
# there is no data for 2 at 12 at VQD.
# there is no data for 3 at 0 at VQD.
# there is no data for 3 at 12 at VQD.
# there is no data for 4 at 0 at VQD.
# there is no data for 4 at 12 at VQD.
# there is no data for 5 at 0 at VQD.
# there is no data for 5 at 12 at VQD.
# there is no data for 6 at 0 at VQD.
# there is no data for 6 at 12 at VQD.
# there is no data for 7 at 0 at VQD.
# there is no data for 7 at 12 at VQD.
# there is no data for 8 at 0 at VQD.
# there is no data for 8 at 12 at VQD.
# there is no data for 9 at 0 at VQD.
# there is no data for 9 at 12 at VQD.
# there is no data for 10 at 0 at VQD.
# there is no data for 10 at 12 at VQD.
# there is no data for 11 at 0 at VQD.
# there is no data for 11 at 12 at VQD.
# there is no data for 12 at 0 at VQD.
# there is no data for 12 at 12 at VQD.
# there is no data for 13 at 0 at VQD.
# there is no data for 13 at 12 at VQD.
# there is no data for 14 at 0 at VQD.
# there is no data for 14 at 12 at VQD.
# there is no data for 15 at 0 at VQD.
# there is no data for 15 at 12 at VQD.
# there is no data for 16 at 0 at VQD.
# there is no data for 16 at 12 at VQD.
# there is no data for 17 at 0 at VQD.
# there is no data for 17 at 12 at VQD.
# there is no data for 18 at 0 at VQD.
# there is no data for 18 at 12 at VQD.
# there is no data for 19 at 0 at VQD.
# there is no data for 19 at 12 at VQD.
# there is no data for 20 at 0 at VQD.
# there is no data for 20 at 12 at VQD.
# there is no data for 21 at 0 at VQD.
# there is no data for 21 at 12 at VQD.
# there is no data for 22 at 0 at VQD.
# there is no data for 22 at 12 at VQD.
# there is no data for 23 at 0 at VQD.
# there is no data for 23 at 12 at VQD.
# there is no data for 24 at 0 at VQD.
# there is no data for 24 at 12 at VQD.
# there is no data for 25 at 0 at VQD.
# there is no data for 25 at 12 at VQD.
# there is no data for 26 at 0 at VQD.
# there is no data for 26 at 12 at VQD.
# there is no data for 27 at 0 at VQD.
# there is no data for 27 at 12 at VQD.
# there is no data for 28 at 0 at VQD.
# there is no data for 28 at 12 at VQD.
# there is no data for 29 at 0 at VQD.
# there is no data for 29 at 12 at VQD.
# there is no data for 30 at 0 at VQD.
# there is no data for 30 at 12 at VQD.
# ['VQD, nan, nan, nan, 0, 0, 0, 51.45, -90.22 \n’']
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/lib/function_base.py:495: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['WSE, 29.458346136113718, 0.0022929338245683477, -11.255, 6, 0, 0, 53.53, -114.1 \n’']
# ['YZT, 30.58375357841212, 1.3306335542867171, 2.9066666666666667, 6, 0, 0, 50.68, -127.36 \n’']
# 2:44:20.637732
